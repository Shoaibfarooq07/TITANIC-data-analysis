# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby(["Sex"])["Age"].mean
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.groupby(["Survived","Sex"])["Survived"].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
df.groupby("Survived")["Fare"].mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.groupby(["Survived","Sex"])["Survived"].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
grouped = df.groupby(["Survived", "Sex"])["Survived"].count()
grouped.plot(kind='bar', figsize=(8, 6),color=["red","red","black","black"])
plt.title("Survival Count by gender")
plt.show()

# %%
grouped = df.groupby(["Survived", "Sex"])["Survived"].count()
grouped.plot(kind='pie', figsize=(10, 6))
plt.title("Survival Count by Sex")
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print("oldest passenger on the ship:",df["Age"].max(),'years')
print("youngest passenger on the ship:",df["Age"].min(),'years')
# Out:
# oldest passenger on the ship: 80.0 years
# youngest passenger on the ship: 0.42 years

# %%
print("average age of the passengers on the ship:",df["Age"].mean(),'years')
# Out:
# average age of the passengers on the ship: 29.69911764705882 years

# %%
youngest = df['Age'].min()
average = df['Age'].mean()
oldest = df['Age'].max()
labels = ['Youngest', 'Average', 'Oldest']
values = [youngest, average, oldest]

plt.figure(figsize=(6, 4))
plt.bar(labels, values,color=["red","green","blue"])
plt.title('Age Statistics of Passengers')
# Out:
# Text(0.5, 1.0, 'Age Statistics of Passengers')

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]=df["Age"].fillna(round(df["Age"].mean(), 2))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(subset=["Embarked"],inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
grouped_1=df.groupby(["Pclass"])["Fare"].mean()
print(grouped_1)
# Out:
# Pclass
# 1    84.193516
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
grouped_2=df.groupby(["Pclass"])["Fare"].max()
print(grouped_2)
plt.figure(figsize=(7, 5))
plt.bar(grouped_2.index.astype(str), grouped_2.values, color=["black", "red", "brown"])
plt.title("Maximum Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Maximum Fare")
plt.show()
# Out:
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
grouped_1=df.groupby(["Pclass"])["Fare"].mean()
plt.figure(figsize=(7,5))
plt.bar(grouped_1.index.astype(str),grouped_1.values,color=["red","blue","green"])
plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Fare")
plt.show()

# %%
grouped = df.groupby("Sex")["Survived"].mean()
print(grouped)
plt.bar(grouped.index, grouped.values, color=["red", "lightblue"])
plt.title("Survival Rate by Gender")
plt.ylabel("Survival Rate")
plt.show()
# Out:
# Sex
# female    0.740385
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.groupby("Survived")["Fare"].mean()
# Out:
# Survived
# 0    22.117887
# 1    48.209498
# Name: Fare, dtype: float64

# %%
groupby_5=df.groupby("Survived")["Fare"].mean()
plt.bar(groupby_5.index,groupby_5.values,color=["orange","blue"])
plt.title("number of survivors by fair")
plt.ylabel("Survivors")
plt.xlabel("orange refers to zero survivors and blue refers to survivors")
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.groupby(["Embarked"])["Survived"].count()
# Out:
# Embarked
# C    168
# Q     77
# S    644
# Name: Survived, dtype: int64

# %%
counts=df.groupby(["Embarked"])["Survived"].count()
counts.plot(kind='bar')  
plt.title('Number of Passengers by Embarkation Port')
plt.xlabel('Embarked')
plt.ylabel('Passenger Count')
plt.show()

# %%
counts=df.groupby(["Embarked"])["Survived"].count()
plt.title('Number of Passengers by Embarkation Port')
plt.xlabel('Embarked')
plt.ylabel('Passenger Count')
plt.show()

# %%
counts = df.groupby(["Embarked"])["Survived"].count()


plt.barh(counts.index, counts.values, color=['darkblue','red','green'])

plt.title('Number of Passengers by Embarkation Port')
plt.xlabel('Passenger Count')
plt.ylabel('Embarked')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.groupby("Sex")["PassengerId"].count()
# Out:
# Sex
# female    312
# male      577
# Name: PassengerId, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
bins=[0 , 12 , 18 , 35 , 60 , 80]
labels=["child" , "teen" , "Young adult" ,"adult", "senior"]

df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
survival_by_age_group=df.groupby(["AgeGroup"],observed=True)["Survived"].mean()
print(survival_by_age_group)
# Out:
# AgeGroup
# child          0.579710
# teen           0.428571
# Young adult    0.353271
# adult          0.396907
# senior         0.190476
# Name: Survived, dtype: float64

# %%
age_group_survival = df.groupby('AgeGroup',observed=True)['Survived'].agg(['sum', 'count'])
print(age_group_survival)
# Out:
#              sum  count
# AgeGroup
# child         40     69
# teen          30     70
# Young adult  189    535
# adult         77    194
# senior         4     21

# %%
age_group_survivals = df.groupby('AgeGroup', observed=True)['Survived'].agg(['sum', 'count'])
print(age_group_survivals)
age_group_survivals.plot(kind='barh')


plt.xlabel('Survival Percentage')
plt.ylabel('Age Group')
plt.title('Survival Rate by Age Group')
plt.show()
# Out:
#              sum  count
# AgeGroup
# child         40     69
# teen          30     70
# Young adult  189    535
# adult         77    194
# senior         4     21

# %%
percentage=(age_group_survivals["sum"]/age_group_survivals["count"]) * 100
print(percentage)
percentage.plot(kind='barh',color=["red","blue","green","black","brown","purple"])


plt.xlabel('Survival Percentage')
plt.ylabel('Age Group')
plt.title('Survival Rate by Age Group')
plt.show()
# Out:
# AgeGroup
# child          57.971014
# teen           42.857143
# Young adult    35.327103
# adult          39.690722
# senior         19.047619
# dtype: float64

# %%
plt.barh(survival_by_age_group.index, survival_by_age_group.values, color=['darkblue','red','green','yellow','brown',])

plt.title('survival rate by age group')
plt.xlabel('survival rate')
plt.ylabel('age group')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
grouped_3 = df.groupby("Pclass")["Survived"].sum()
print(grouped_3)


plt.bar(grouped_3.index, grouped_3.values, color=["green", "yellow", "darkblue"])
plt.title("Number of Survivors by Class")
plt.ylabel("Survivors")
plt.xlabel("Passenger Class")


plt.xticks(grouped_3.index, ["Upper Class", "Middle Class", "Lower Class"])

plt.show()
# Out:
# Pclass
# 1    134
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
df.tail(25)
# Out:
#      PassengerId  Survived  Pclass  \
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# ...

# %%
labels = ["Upper Class", "Middle Class", "Lower Class"]

plt.pie(grouped_3.values, labels=labels, autopct="%1.1f%%", startangle=140, colors=["red", "yellow", "green"])
plt.title("Survivors by Passenger Class")
plt.axis("equal")  
plt.show()

# %%
survival_by_gender = df.groupby('Sex')['Survived'].agg(['sum', 'count'])
print(survival_by_gender)
# Out:
#         sum  count
# Sex
# female  231    312
# male    109    577

# %%
labels = survival_by_gender.index  
sizes = survival_by_gender['sum']  

# Plotting
plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Survivors by Gender')
plt.axis('equal')  
plt.show()

# %%
survival_by_gender=(survival_by_gender['sum'] / survival_by_gender['count']) * 100
print(survival_by_gender)
survival_by_gender.plot(kind='bar',color=["red","yellow"])

plt.ylabel('Survival Percentage')
plt.xlabel('Sex')
plt.title('Survival Rate by Gender')
plt.show()
# Out:
# Sex
# female    74.038462
# male      18.890815
# dtype: float64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'AgeGroup'],
#       dtype='object')

# %%
survival_by_class=df.groupby("Pclass")["Survived"].agg(["sum","count"]) 
print(survival_by_class)
# Out:
#         sum  count
# Pclass
# 1       134    214
# 2        87    184
# 3       119    491

# %%
avg_sur_class=(survival_by_class["sum"]/survival_by_class["count"]) * 100
print(avg_sur_class)
# Out:
# Pclass
# 1    62.616822
# 2    47.282609
# 3    24.236253
# dtype: float64

# %%
avg_sur_class.plot(kind="bar",color=["red","blue","yellow"])
plt.ylabel("survival percent by class")
plt.xlabel("class")
plt.title("survival by class") 
plt.show()

# %%
port_survival_rate=df.groupby("Embarked")["Survived"].agg(["sum","count"])
print(port_survival_rate)
# Out:
#           sum  count
# Embarked
# C          93    168
# Q          30     77
# S         217    644

# %%
percentage_survival=(port_survival_rate["sum"]/port_survival_rate["count"]) * 100
print(percentage_survival)
# Out:
# Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# dtype: float64

# %%
percentage_survival.plot(kind="bar",color=["black","green","red"])
plt.ylabel("embark survival percentage")
plt.xlabel("embarked cities")
plt.title("survival rate from cities")
plt.show()

# %%
grouped_8=df.groupby(["Pclass","Sex"])["Survived"].agg(["sum","count"])
print(grouped_8)
# Out:
#                sum  count
# Pclass Sex
# 1      female   89     92
#        male     45    122
# 2      female   70     76
#        male     17    108
# 3      female   72    144
#        male     47    347

# %%
avg=(grouped_8["sum"]/grouped_8["count"]) * 100
print(avg)
# Out:
# Pclass  Sex
# 1       female    96.739130
#         male      36.885246
# 2       female    92.105263
#         male      15.740741
# 3       female    50.000000
#         male      13.544669
# dtype: float64

# %%
avg = avg.unstack()
avg.plot(kind="bar")
plt.ylabel('Survival Percentage')
plt.xlabel('Passenger Class')
plt.title('Survival Rate by Class and Gender')
plt.show()

# %%
avg = avg.unstack()
avg.plot(kind="bar",color=["red","black"])
plt.ylabel('Survival Percentage')
plt.xlabel('Passenger Class')
plt.title('Survival Rate by Class and Gender ') 
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'AgeGroup'],
#       dtype='object')

# %%
cab=df.groupby("Cabin")["Survived"].sum()
print(cab)
# Out:
# Cabin
# A10    0
# A14    0
# A16    1
# A19    0
# A20    1
#       ..
# F33    3
# F38    0
# F4     2
# G6     2
# T      0
# Name: Survived, Length: 146, dtype: int64

# %%
df.drop("Cabin",axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# AgeGroup         0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    312
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
